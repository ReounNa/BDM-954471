# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv', sep=',', header = 0)
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
df.groupby('NAME_HOUSING_TYPE')['NAME_HOUSING_TYPE'].count()
# Out:
# NAME_HOUSING_TYPE
# Co-op apartment          1539
# House / apartment      393831
# Municipal apartment     14214
# Office apartment         3922
# Rented apartment         5974
# With parents            19077
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
df.groupby('NAME_FAMILY_STATUS')['NAME_FAMILY_STATUS'].count()
# Out:
# NAME_FAMILY_STATUS
# Civil marriage           36532
# Married                 299828
# Separated                27251
# Single / not married     55271
# Widow                    19675
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis = 0)

# %%
df_clean.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop = df_clean.drop(['DAYS_BIRTH','FLAG_EMAIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_MOBIL','CODE_GENDER'], axis=1)

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop
# Out:
#              ID FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 2       5008806            Y               Y             0          112500.0
# 3       5008808            N               Y             0          270000.0
# 4       5008809            N               Y             0          270000.0
# 5       5008810            N               Y             0          270000.0
# 6       5008811            N               Y             0          270000.0
# ...         ...          ...             ...           ...               ...
# 438541  6837707            N               Y             0          202500.0
# 438548  6839936            Y               Y             1          135000.0
# 438553  6840222            N               N             0          103500.0
# 438554  6841878            N               N             0           54000.0
# 438556  6842885            N               Y             0          121500.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2                    Working  Secondary / secondary special
# 3       Commercial associate  Secondary / secondary special
# 4       Commercial associate  Secondary / secondary special
# 5       Commercial associate  Secondary / secondary special
# 6       Commercial associate  Secondary / secondary special
# ...                      ...                            ...
# 438541               Working               Higher education
# 438548               Working  Secondary / secondary special
# 438553               Working  Secondary / secondary special
# 438554  Commercial associate               Higher education
# 438556               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_EMPLOYED  \
# 2                    Married  House / apartment          -1134
# 3       Single / not married  House / apartment          -3051
# 4       Single / not married  House / apartment          -3051
# 5       Single / not married  House / apartment          -3051
# 6       Single / not married  House / apartment          -3051
# ...                      ...                ...            ...
# 438541        Civil marriage  House / apartment          -2309
# 438548               Married  House / apartment          -2095
# 438553  Single / not married  House / apartment          -3007
# 438554  Single / not married       With parents           -372
# 438556               Married  House / apartment          -1201
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 2       Security staff              2.0
# 3          Sales staff              1.0
# 4          Sales staff              1.0
# 5          Sales staff              1.0
# 6          Sales staff              1.0
# ...                ...              ...
# 438541        Laborers              2.0
# 438548        Laborers              3.0
# 438553        Laborers              1.0
# 438554     Sales staff              1.0
# 438556     Sales staff              2.0
#
# [304354 rows x 12 columns]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop['FLAG_OWN_CAR'] = pd.factorize(df_clean_drop['FLAG_OWN_CAR'])[0]
df_clean_drop['FLAG_OWN_REALTY'] = pd.factorize(df_clean_drop['FLAG_OWN_REALTY'])[0]
df_clean_drop['NAME_INCOME_TYPE'] = pd.factorize(df_clean_drop['NAME_INCOME_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean_drop['NAME_EDUCATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS'] = pd.factorize(df_clean_drop['NAME_FAMILY_STATUS'])[0]
df_clean_drop['NAME_HOUSING_TYPE'] = pd.factorize(df_clean_drop['NAME_HOUSING_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE'] = pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop
# Out:
#              ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2       5008806             0                0             0
# 3       5008808             1                0             0
# 4       5008809             1                0             0
# 5       5008810             1                0             0
# 6       5008811             1                0             0
# ...         ...           ...              ...           ...
# 438541  6837707             1                0             0
# 438548  6839936             0                0             1
# 438553  6840222             1                1             0
# 438554  6841878             1                1             0
# 438556  6842885             1                0             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 2               112500.0                 0                    0
# 3               270000.0                 1                    0
# 4               270000.0                 1                    0
# 5               270000.0                 1                    0
# 6               270000.0                 1                    0
# ...                  ...               ...                  ...
# 438541          202500.0                 0                    1
# 438548          135000.0                 0                    0
# 438553          103500.0                 0                    0
# 438554           54000.0                 1                    1
# 438556          121500.0                 0                    0
#
#         NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_EMPLOYED  OCCUPATION_TYPE  \
# 2                        0                  0          -1134                0
# 3                        1                  0          -3051                1
# 4                        1                  0          -3051                1
# 5                        1                  0          -3051                1
# 6                        1                  0          -3051                1
# ...                    ...                ...            ...              ...
# 438541                   2                  0          -2309                3
# 438548                   0                  0          -2095                3
# 438553                   1                  0          -3007                3
# 438554                   1                  3           -372                1
# 438556                   0                  0          -1201                1
#
#         CNT_FAM_MEMBERS
# 2                   2.0
# 3                   1.0
# 4                   1.0
# 5                   1.0
# 6                   1.0
# ...                 ...
# 438541              2.0
# 438548              3.0
# 438553              1.0
# 438554              1.0
# 438556              2.0
#
# [304354 rows x 12 columns]

# %%
X = df_clean_drop.values #featureข้อมูล
X.shape
# Out:
# (304354, 12)

# %% [markdown]
# # df label - คำตอบ(y)

# %%
df_label = pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv', sep=',', header = 0)
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %% [markdown]
# 0: 1-29 days past due 1: 30-59 days past due 2: 60-89 days overdue 3: 90-119 days overdue 4: 120-149 days overdue 5: Overdue or bad debts, write-offs for more than 150 days C: paid off that month X: No loan for the month

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label['STATUS'], labels = pd.factorize(df_label['STATUS'])

# %%
labels 
#0 คือ X , 2 คือ C
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label['STATUS'] != 0 # ไม่เท่ากับ X
# Out:
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: STATUS, Length: 1048575, dtype: bool

# %%
df_label_clean = df_label[df_label['STATUS']!=0]
# เอา X ออกเพราะ Xคือคนที่ไม่ยืมเงิน ไม่ใช้คิดเอาออกไป

# %%
df_label_clean
# Out:
#               ID  MONTHS_BALANCE  STATUS
# 1        5001711              -1       1
# 2        5001711              -2       1
# 3        5001711              -3       1
# 4        5001712               0       2
# 5        5001712              -1       2
# ...          ...             ...     ...
# 1048570  5150487             -25       2
# 1048571  5150487             -26       2
# 1048572  5150487             -27       2
# 1048573  5150487             -28       2
# 1048574  5150487             -29       2
#
# [839345 rows x 3 columns]

# %% [markdown]
# # แยกลูกหนี้ออกเป็น2กลุ่ม

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 10
#  '1', '2', '3', '4', '5'] // คือ เลข 3,4,5,6,7
# ค่ามากกว่า2คือคนจ่ายช้ามาก เปลี่ยนค่าให้อ่านง่าย ว่ากลุ่มพวกนนี้คือจ่ายช้า -ลูกหนี้ไม่ดี
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0
#  '0', 'C' // คือ เลข 1 , 2 
# กลุ่มจ่ายหนี้โอเค -ลูกหนี้ดี
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0     825151
# 10     14194
# Name: STATUS, dtype: int64

# %% [markdown]
# # จะได้ว่า STATUS = 0 คือ คนที่จ่ายตรงทุกรอบ

# %%
df_label_clean.groupby('ID').mean()
# จะได้ว่า STATUS = 0 คือ คนที่จ่ายตรงทุกรอบ
# Out:
#          MONTHS_BALANCE    STATUS
# ID
# 5001711       -2.000000  0.000000
# 5001712       -9.000000  0.000000
# 5001717      -10.500000  0.000000
# 5001718      -18.724138  0.689655
# 5001719      -21.000000  0.000000
# ...                 ...       ...
# 5150480      -36.500000  0.000000
# 5150482      -19.500000  0.000000
# 5150484       -6.000000  0.000000
# 5150485       -0.500000  0.000000
# 5150487      -14.500000  0.000000
#
# [41449 rows x 2 columns]

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
#จัดให้เลขสวย
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group
# Out:
#          MONTHS_BALANCE  STATUS
# ID
# 5001711       -2.000000     0.0
# 5001712       -9.000000     0.0
# 5001717      -10.500000     0.0
# 5001718      -18.724138     1.0
# 5001719      -21.000000     0.0
# ...                 ...     ...
# 5150480      -36.500000     0.0
# 5150482      -19.500000     0.0
# 5150484       -6.000000     0.0
# 5150485       -0.500000     0.0
# 5150487      -14.500000     0.0
#
# [41449 rows x 2 columns]

# %% [markdown]
# # หา/ทำ y กับ X_final

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
client_id = df_label_group.index.values # .index เพราะ id โดน groupby เลย กลายเป็น index
client_label = df_label_group['STATUS'].values

# %%
X_clien_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
# X = df_clean_drop.values #featureข้อมูล
# X.shape

# %%
real_client_id = [item for item in X_clien_id if item in client_id]

# %%
len(real_client_id)
# Out:
# 22737

# %%
y = [client_label[np.where(client_id == item)][0] for item in real_client_id] 
# แปลงข้อมูล y จาก list เป็๋น np.array จะได้ดูไม่เละ ชีวิตจะง่าย

# %%
X_final = [X[np.where(X_clien_id == item), :][0] for item in real_client_id]

# %%
X_final[0]
# Out:
# array([[ 5.008806e+06,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#          1.125000e+05,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#          0.000000e+00, -1.134000e+03,  0.000000e+00,  2.000000e+00]])

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 12)

# %%
len(y)
# Out:
# 22737

# %% [markdown]
# # Under sampling

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=1)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 16}
# 10CV accuracy : 53.09909218769978

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 52.103559870550164

# %% [markdown]
# #
# # Deep Learning

# %%
# !pip install tensorflow==2.0.0-beta1
import tensorflow as tf
# Out:
# Collecting tensorflow==2.0.0-beta1
#   Downloading tensorflow-2.0.0b1-cp37-cp37m-manylinux1_x86_64.whl (88.7 MB)
#      |████████████████████████████████| 88.7 MB 6.3 MB/s eta 0:00:01     |███████████▍                    | 31.7 MB 848 kB/s eta 0:01:08     |████████████████▋               | 46.1 MB 5.8 MB/s eta 0:00:08
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (1.12.1)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (0.36.2)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (3.17.3)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (1.19.5)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (1.1.2)
# Collecting tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501
#   Downloading tf_estimator_nightly-1.14.0.dev2019060501-py2.py3-none-any.whl (496 kB)
#      |████████████████████████████████| 496 kB 46.4 MB/s eta 0:00:01
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 4.5 MB/s  eta 0:00:01
# Collecting tb-nightly<1.14.0a20190604,>=1.14.0a20190603
#   Downloading tb_nightly-1.14.0a20190603-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 44.0 MB/s eta 0:00:01
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (1.32.0)
# Requirement already satisfied: gast>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.0.0-beta1) (0.12.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-beta1) (2.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (49.6.0.post20210108)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (2.0.1)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from markdown>=2.6.8->tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (3.4.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (3.7.4.3)
# Installing collected packages: tf-estimator-nightly, tb-nightly, keras-applications, astor, tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed astor-0.8.1 keras-applications-1.0.8 tb-nightly-1.14.0a20190603 tensorflow-2.0.0b1 tf-estimator-nightly-1.14.0.dev2019060501
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# model แรกที่เราจะสร้าง

# %%
X_real_final.shape
# Out:
# (22737, 12)

# %%
tf.compat.v1.reset_default_graph() # Clear Model
np.random.seed(1) # Fix Randomness
tf.compat.v1.random.set_random_seed(1) # Fix Randomness
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(8, activation='relu', input_shape=(12,)), #มี12featureก็เขียนไป12
  tf.keras.layers.Dense(4, activation='relu'),
  tf.keras.layers.Dense(2, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')     #sigmoidปิดเสมอถ้ามี2ค่า0กับ1
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 104
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 153
# Trainable params: 153
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) #คำคอบมีค่า0กับ1ใช้ binary_crossentropy

# %%
#Train Model
train_acc = list()
val_acc = list()
for i in range(0,500):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)

#batch_size = 200เอาข้อมูลไปtrainทีละ200ตัว ใน 500รอบ
# Out:
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 95us/sample - loss: 0.6949 - accuracy: 0.4994 - val_loss: 0.6936 - val_accuracy: 0.5035
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6932 - accuracy: 0.5085 - val_loss: 0.6930 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6927 - accuracy: 0.5188 - val_loss: 0.6929 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6925 - accuracy: 0.5201 - val_loss: 0.6928 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6924 - accuracy: 0.5211 - val_loss: 0.6928 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6922 - accuracy: 0.5244 - val_loss: 0.6928 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6922 - accuracy: 0.5211 - val_loss: 0.6927 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6920 - accuracy: 0.5188 - val_loss: 0.6927 - val_accuracy: 0.5147
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6919 - accuracy: 0.5242 - val_loss: 0.6927 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6918 - accuracy: 0.5237 - val_loss: 0.6926 - val_accuracy: 0.5116
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6917 - accuracy: 0.5183 - val_loss: 0.6926 - val_accuracy: 0.5116
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6916 - accuracy: 0.5257 - val_loss: 0.6926 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6915 - accuracy: 0.5267 - val_loss: 0.6926 - val_accuracy: 0.5147
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6913 - accuracy: 0.5264 - val_loss: 0.6926 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6911 - accuracy: 0.5297 - val_loss: 0.6925 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6910 - accuracy: 0.5239 - val_loss: 0.6926 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6908 - accuracy: 0.5249 - val_loss: 0.6925 - val_accuracy: 0.5096
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6908 - accuracy: 0.5312 - val_loss: 0.6926 - val_accuracy: 0.5066
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6905 - accuracy: 0.5333 - val_loss: 0.6926 - val_accuracy: 0.5056
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6902 - accuracy: 0.5295 - val_loss: 0.6927 - val_accuracy: 0.5086
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6900 - accuracy: 0.5376 - val_loss: 0.6928 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6898 - accuracy: 0.5355 - val_loss: 0.6927 - val_accuracy: 0.5035
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6895 - accuracy: 0.5338 - val_loss: 0.6926 - val_accuracy: 0.5056
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 13us/sample - loss: 0.6893 - accuracy: 0.5378 - val_loss: 0.6926 - val_accuracy: 0.5066
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6891 - accuracy: 0.5391 - val_loss: 0.6927 - val_accuracy: 0.5086
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6890 - accuracy: 0.5424 - val_loss: 0.6928 - val_accuracy: 0.5137
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6888 - accuracy: 0.5419 - val_loss: 0.6925 - val_accuracy: 0.5137
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6886 - accuracy: 0.5439 - val_loss: 0.6926 - val_accuracy: 0.5086
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6885 - accuracy: 0.5403 - val_loss: 0.6927 - val_accuracy: 0.5116
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6883 - accuracy: 0.5436 - val_loss: 0.6926 - val_accuracy: 0.5116
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6882 - accuracy: 0.5490 - val_loss: 0.6925 - val_accuracy: 0.5096
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6880 - accuracy: 0.5520 - val_loss: 0.6926 - val_accuracy: 0.5137
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6878 - accuracy: 0.5474 - val_loss: 0.6926 - val_accuracy: 0.5147
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6877 - accuracy: 0.5515 - val_loss: 0.6924 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6876 - accuracy: 0.5449 - val_loss: 0.6928 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6874 - accuracy: 0.5517 - val_loss: 0.6924 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6874 - accuracy: 0.5507 - val_loss: 0.6924 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6872 - accuracy: 0.5441 - val_loss: 0.6928 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6870 - accuracy: 0.5530 - val_loss: 0.6924 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6868 - accuracy: 0.5490 - val_loss: 0.6926 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6868 - accuracy: 0.5512 - val_loss: 0.6925 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6865 - accuracy: 0.5540 - val_loss: 0.6927 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6863 - accuracy: 0.5540 - val_loss: 0.6927 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6862 - accuracy: 0.5563 - val_loss: 0.6925 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6860 - accuracy: 0.5543 - val_loss: 0.6927 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6859 - accuracy: 0.5527 - val_loss: 0.6927 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6857 - accuracy: 0.5586 - val_loss: 0.6926 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6856 - accuracy: 0.5611 - val_loss: 0.6929 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6855 - accuracy: 0.5581 - val_loss: 0.6926 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6853 - accuracy: 0.5586 - val_loss: 0.6930 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6851 - accuracy: 0.5560 - val_loss: 0.6929 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6851 - accuracy: 0.5563 - val_loss: 0.6928 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6849 - accuracy: 0.5624 - val_loss: 0.6929 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6848 - accuracy: 0.5586 - val_loss: 0.6930 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6847 - accuracy: 0.5593 - val_loss: 0.6932 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6847 - accuracy: 0.5570 - val_loss: 0.6934 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6844 - accuracy: 0.5593 - val_loss: 0.6931 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6844 - accuracy: 0.5616 - val_loss: 0.6933 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6845 - accuracy: 0.5601 - val_loss: 0.6936 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6842 - accuracy: 0.5593 - val_loss: 0.6933 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6840 - accuracy: 0.5619 - val_loss: 0.6934 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6839 - accuracy: 0.5581 - val_loss: 0.6936 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6838 - accuracy: 0.5631 - val_loss: 0.6935 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6837 - accuracy: 0.5619 - val_loss: 0.6936 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6837 - accuracy: 0.5593 - val_loss: 0.6939 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6836 - accuracy: 0.5608 - val_loss: 0.6940 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6837 - accuracy: 0.5621 - val_loss: 0.6937 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6836 - accuracy: 0.5629 - val_loss: 0.6942 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6835 - accuracy: 0.5613 - val_loss: 0.6939 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6834 - accuracy: 0.5608 - val_loss: 0.6941 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6830 - accuracy: 0.5631 - val_loss: 0.6942 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6830 - accuracy: 0.5626 - val_loss: 0.6943 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6830 - accuracy: 0.5639 - val_loss: 0.6942 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6829 - accuracy: 0.5662 - val_loss: 0.6948 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6828 - accuracy: 0.5662 - val_loss: 0.6947 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6826 - accuracy: 0.5641 - val_loss: 0.6945 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6825 - accuracy: 0.5649 - val_loss: 0.6946 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6825 - accuracy: 0.5646 - val_loss: 0.6950 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6825 - accuracy: 0.5674 - val_loss: 0.6949 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6822 - accuracy: 0.5664 - val_loss: 0.6949 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6823 - accuracy: 0.5634 - val_loss: 0.6948 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6821 - accuracy: 0.5674 - val_loss: 0.6951 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6820 - accuracy: 0.5677 - val_loss: 0.6950 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6819 - accuracy: 0.5694 - val_loss: 0.6952 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6820 - accuracy: 0.5677 - val_loss: 0.6950 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6819 - accuracy: 0.5669 - val_loss: 0.6949 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6819 - accuracy: 0.5654 - val_loss: 0.6953 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6817 - accuracy: 0.5697 - val_loss: 0.6950 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6813 - accuracy: 0.5717 - val_loss: 0.6953 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6812 - accuracy: 0.5745 - val_loss: 0.6952 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6811 - accuracy: 0.5735 - val_loss: 0.6954 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6811 - accuracy: 0.5735 - val_loss: 0.6954 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6810 - accuracy: 0.5732 - val_loss: 0.6955 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6810 - accuracy: 0.5699 - val_loss: 0.6952 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6811 - accuracy: 0.5732 - val_loss: 0.6958 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6807 - accuracy: 0.5674 - val_loss: 0.6953 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6807 - accuracy: 0.5694 - val_loss: 0.6957 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6804 - accuracy: 0.5710 - val_loss: 0.6955 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6804 - accuracy: 0.5694 - val_loss: 0.6959 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6804 - accuracy: 0.5707 - val_loss: 0.6963 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6803 - accuracy: 0.5705 - val_loss: 0.6956 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6805 - accuracy: 0.5742 - val_loss: 0.6961 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6802 - accuracy: 0.5725 - val_loss: 0.6961 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6799 - accuracy: 0.5720 - val_loss: 0.6961 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6800 - accuracy: 0.5720 - val_loss: 0.6960 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6799 - accuracy: 0.5699 - val_loss: 0.6960 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6798 - accuracy: 0.5699 - val_loss: 0.6963 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6796 - accuracy: 0.5710 - val_loss: 0.6960 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6795 - accuracy: 0.5699 - val_loss: 0.6960 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6795 - accuracy: 0.5702 - val_loss: 0.6963 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6798 - accuracy: 0.5722 - val_loss: 0.6967 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6794 - accuracy: 0.5722 - val_loss: 0.6958 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6793 - accuracy: 0.5689 - val_loss: 0.6962 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6794 - accuracy: 0.5720 - val_loss: 0.6964 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6792 - accuracy: 0.5699 - val_loss: 0.6963 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6791 - accuracy: 0.5692 - val_loss: 0.6961 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6791 - accuracy: 0.5705 - val_loss: 0.6963 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6788 - accuracy: 0.5694 - val_loss: 0.6966 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6792 - accuracy: 0.5654 - val_loss: 0.6964 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6797 - accuracy: 0.5707 - val_loss: 0.6969 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6787 - accuracy: 0.5702 - val_loss: 0.6961 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6789 - accuracy: 0.5689 - val_loss: 0.6962 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6783 - accuracy: 0.5684 - val_loss: 0.6969 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6787 - accuracy: 0.5725 - val_loss: 0.6963 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6783 - accuracy: 0.5717 - val_loss: 0.6967 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6780 - accuracy: 0.5717 - val_loss: 0.6966 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6783 - accuracy: 0.5735 - val_loss: 0.6970 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6785 - accuracy: 0.5697 - val_loss: 0.6963 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6780 - accuracy: 0.5722 - val_loss: 0.6966 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6779 - accuracy: 0.5712 - val_loss: 0.6969 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6777 - accuracy: 0.5758 - val_loss: 0.6962 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6777 - accuracy: 0.5707 - val_loss: 0.6967 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6777 - accuracy: 0.5732 - val_loss: 0.6968 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6773 - accuracy: 0.5722 - val_loss: 0.6966 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6773 - accuracy: 0.5740 - val_loss: 0.6966 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6772 - accuracy: 0.5740 - val_loss: 0.6970 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6773 - accuracy: 0.5735 - val_loss: 0.6969 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6771 - accuracy: 0.5715 - val_loss: 0.6968 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6769 - accuracy: 0.5742 - val_loss: 0.6968 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6769 - accuracy: 0.5742 - val_loss: 0.6968 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6767 - accuracy: 0.5753 - val_loss: 0.6970 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6770 - accuracy: 0.5750 - val_loss: 0.6970 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6769 - accuracy: 0.5750 - val_loss: 0.6967 - val_accuracy: 0.5399
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6766 - accuracy: 0.5763 - val_loss: 0.6974 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6767 - accuracy: 0.5737 - val_loss: 0.6973 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6767 - accuracy: 0.5745 - val_loss: 0.6968 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6763 - accuracy: 0.5773 - val_loss: 0.6975 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6762 - accuracy: 0.5712 - val_loss: 0.6972 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6763 - accuracy: 0.5742 - val_loss: 0.6973 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6762 - accuracy: 0.5760 - val_loss: 0.6972 - val_accuracy: 0.5379
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6761 - accuracy: 0.5758 - val_loss: 0.6975 - val_accuracy: 0.5399
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6761 - accuracy: 0.5727 - val_loss: 0.6973 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6760 - accuracy: 0.5707 - val_loss: 0.6972 - val_accuracy: 0.5410
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6758 - accuracy: 0.5748 - val_loss: 0.6975 - val_accuracy: 0.5379
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6758 - accuracy: 0.5727 - val_loss: 0.6976 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6754 - accuracy: 0.5727 - val_loss: 0.6976 - val_accuracy: 0.5399
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6754 - accuracy: 0.5765 - val_loss: 0.6977 - val_accuracy: 0.5389
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6753 - accuracy: 0.5740 - val_loss: 0.6976 - val_accuracy: 0.5420
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6754 - accuracy: 0.5778 - val_loss: 0.6974 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 13us/sample - loss: 0.6753 - accuracy: 0.5707 - val_loss: 0.6977 - val_accuracy: 0.5420
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6753 - accuracy: 0.5712 - val_loss: 0.6976 - val_accuracy: 0.5410
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 13us/sample - loss: 0.6755 - accuracy: 0.5793 - val_loss: 0.6979 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6756 - accuracy: 0.5745 - val_loss: 0.6978 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6756 - accuracy: 0.5818 - val_loss: 0.6977 - val_accuracy: 0.5379
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 14us/sample - loss: 0.6751 - accuracy: 0.5737 - val_loss: 0.6981 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6747 - accuracy: 0.5740 - val_loss: 0.6977 - val_accuracy: 0.5410
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6747 - accuracy: 0.5783 - val_loss: 0.6979 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6746 - accuracy: 0.5745 - val_loss: 0.6980 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6745 - accuracy: 0.5791 - val_loss: 0.6980 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6744 - accuracy: 0.5742 - val_loss: 0.6982 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6744 - accuracy: 0.5758 - val_loss: 0.6981 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6747 - accuracy: 0.5760 - val_loss: 0.6977 - val_accuracy: 0.5420
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6746 - accuracy: 0.5750 - val_loss: 0.6983 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 13us/sample - loss: 0.6740 - accuracy: 0.5823 - val_loss: 0.6979 - val_accuracy: 0.5420
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6739 - accuracy: 0.5828 - val_loss: 0.6984 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6741 - accuracy: 0.5778 - val_loss: 0.6983 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6740 - accuracy: 0.5783 - val_loss: 0.6979 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6740 - accuracy: 0.5836 - val_loss: 0.6987 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6738 - accuracy: 0.5856 - val_loss: 0.6978 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6738 - accuracy: 0.5894 - val_loss: 0.6986 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6737 - accuracy: 0.5791 - val_loss: 0.6981 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6736 - accuracy: 0.5818 - val_loss: 0.6981 - val_accuracy: 0.5379
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6733 - accuracy: 0.5839 - val_loss: 0.6986 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6736 - accuracy: 0.5796 - val_loss: 0.6988 - val_accuracy: 0.5399
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6733 - accuracy: 0.5813 - val_loss: 0.6993 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6732 - accuracy: 0.5785 - val_loss: 0.6986 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6731 - accuracy: 0.5864 - val_loss: 0.6987 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6735 - accuracy: 0.5803 - val_loss: 0.6988 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6730 - accuracy: 0.5869 - val_loss: 0.6986 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6729 - accuracy: 0.5869 - val_loss: 0.6986 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6727 - accuracy: 0.5854 - val_loss: 0.6995 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6728 - accuracy: 0.5808 - val_loss: 0.6989 - val_accuracy: 0.5399
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6730 - accuracy: 0.5811 - val_loss: 0.6998 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6727 - accuracy: 0.5859 - val_loss: 0.6989 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6729 - accuracy: 0.5836 - val_loss: 0.6994 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6727 - accuracy: 0.5839 - val_loss: 0.6996 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6726 - accuracy: 0.5826 - val_loss: 0.6999 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6723 - accuracy: 0.5834 - val_loss: 0.6995 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6722 - accuracy: 0.5874 - val_loss: 0.6996 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6724 - accuracy: 0.5869 - val_loss: 0.7000 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6721 - accuracy: 0.5831 - val_loss: 0.6999 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6721 - accuracy: 0.5854 - val_loss: 0.7005 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6722 - accuracy: 0.5854 - val_loss: 0.7000 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6723 - accuracy: 0.5849 - val_loss: 0.7006 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6720 - accuracy: 0.5866 - val_loss: 0.6998 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6720 - accuracy: 0.5861 - val_loss: 0.7003 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6719 - accuracy: 0.5877 - val_loss: 0.7007 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6722 - accuracy: 0.5882 - val_loss: 0.7001 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6718 - accuracy: 0.5869 - val_loss: 0.7001 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6718 - accuracy: 0.5882 - val_loss: 0.7004 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6716 - accuracy: 0.5887 - val_loss: 0.7003 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6716 - accuracy: 0.5869 - val_loss: 0.7006 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6717 - accuracy: 0.5861 - val_loss: 0.7006 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6719 - accuracy: 0.5861 - val_loss: 0.7014 - val_accuracy: 0.5379
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6714 - accuracy: 0.5869 - val_loss: 0.7001 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6716 - accuracy: 0.5904 - val_loss: 0.7011 - val_accuracy: 0.5389
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6714 - accuracy: 0.5902 - val_loss: 0.7008 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6715 - accuracy: 0.5884 - val_loss: 0.7019 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6711 - accuracy: 0.5897 - val_loss: 0.7011 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6711 - accuracy: 0.5892 - val_loss: 0.7009 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6716 - accuracy: 0.5889 - val_loss: 0.7021 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6710 - accuracy: 0.5897 - val_loss: 0.7010 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6711 - accuracy: 0.5884 - val_loss: 0.7009 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6711 - accuracy: 0.5892 - val_loss: 0.7016 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6707 - accuracy: 0.5907 - val_loss: 0.7014 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6708 - accuracy: 0.5927 - val_loss: 0.7012 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6709 - accuracy: 0.5892 - val_loss: 0.7020 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6714 - accuracy: 0.5889 - val_loss: 0.7016 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6708 - accuracy: 0.5904 - val_loss: 0.7008 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6708 - accuracy: 0.5904 - val_loss: 0.7012 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6712 - accuracy: 0.5902 - val_loss: 0.7019 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6707 - accuracy: 0.5920 - val_loss: 0.7019 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6704 - accuracy: 0.5922 - val_loss: 0.7021 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6704 - accuracy: 0.5927 - val_loss: 0.7013 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6704 - accuracy: 0.5912 - val_loss: 0.7019 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6701 - accuracy: 0.5922 - val_loss: 0.7014 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6704 - accuracy: 0.5958 - val_loss: 0.7013 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6701 - accuracy: 0.5940 - val_loss: 0.7022 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6701 - accuracy: 0.5914 - val_loss: 0.7020 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6705 - accuracy: 0.5884 - val_loss: 0.7016 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6702 - accuracy: 0.5899 - val_loss: 0.7012 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6700 - accuracy: 0.5899 - val_loss: 0.7026 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6700 - accuracy: 0.5973 - val_loss: 0.7022 - val_accuracy: 0.5420
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6697 - accuracy: 0.5970 - val_loss: 0.7012 - val_accuracy: 0.5369
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6700 - accuracy: 0.5960 - val_loss: 0.7023 - val_accuracy: 0.5389
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6699 - accuracy: 0.5952 - val_loss: 0.7012 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6697 - accuracy: 0.5958 - val_loss: 0.7021 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6696 - accuracy: 0.5937 - val_loss: 0.7019 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6698 - accuracy: 0.5930 - val_loss: 0.7028 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6696 - accuracy: 0.5993 - val_loss: 0.7027 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6696 - accuracy: 0.5950 - val_loss: 0.7014 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6695 - accuracy: 0.5940 - val_loss: 0.7020 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6695 - accuracy: 0.5958 - val_loss: 0.7032 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6693 - accuracy: 0.5963 - val_loss: 0.7014 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6692 - accuracy: 0.5963 - val_loss: 0.7021 - val_accuracy: 0.5319
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6691 - accuracy: 0.5968 - val_loss: 0.7021 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6690 - accuracy: 0.5995 - val_loss: 0.7020 - val_accuracy: 0.5389
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6690 - accuracy: 0.5958 - val_loss: 0.7022 - val_accuracy: 0.5379
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6689 - accuracy: 0.5975 - val_loss: 0.7019 - val_accuracy: 0.5339
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6690 - accuracy: 0.5993 - val_loss: 0.7028 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6694 - accuracy: 0.5958 - val_loss: 0.7015 - val_accuracy: 0.5349
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6695 - accuracy: 0.5983 - val_loss: 0.7031 - val_accuracy: 0.5359
# Train on 3953 samples, validate on 989 samples
# ...
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6641 - accuracy: 0.6036 - val_loss: 0.7074 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6639 - accuracy: 0.6026 - val_loss: 0.7082 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6643 - accuracy: 0.6026 - val_loss: 0.7060 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6640 - accuracy: 0.6028 - val_loss: 0.7057 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6639 - accuracy: 0.6006 - val_loss: 0.7064 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6637 - accuracy: 0.6041 - val_loss: 0.7067 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6634 - accuracy: 0.6051 - val_loss: 0.7066 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6640 - accuracy: 0.6038 - val_loss: 0.7055 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6637 - accuracy: 0.6031 - val_loss: 0.7084 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6642 - accuracy: 0.6041 - val_loss: 0.7058 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6647 - accuracy: 0.5988 - val_loss: 0.7053 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6639 - accuracy: 0.6001 - val_loss: 0.7085 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6636 - accuracy: 0.6033 - val_loss: 0.7068 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6634 - accuracy: 0.6033 - val_loss: 0.7072 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6637 - accuracy: 0.6013 - val_loss: 0.7066 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6634 - accuracy: 0.6038 - val_loss: 0.7078 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6638 - accuracy: 0.6036 - val_loss: 0.7066 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6635 - accuracy: 0.6051 - val_loss: 0.7073 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6639 - accuracy: 0.6041 - val_loss: 0.7067 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6638 - accuracy: 0.6011 - val_loss: 0.7081 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6635 - accuracy: 0.6026 - val_loss: 0.7085 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6641 - accuracy: 0.6003 - val_loss: 0.7066 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6638 - accuracy: 0.6028 - val_loss: 0.7072 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6633 - accuracy: 0.6023 - val_loss: 0.7077 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6634 - accuracy: 0.6021 - val_loss: 0.7079 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6636 - accuracy: 0.6023 - val_loss: 0.7087 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6639 - accuracy: 0.6016 - val_loss: 0.7081 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6642 - accuracy: 0.6008 - val_loss: 0.7075 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6633 - accuracy: 0.6013 - val_loss: 0.7078 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6630 - accuracy: 0.6033 - val_loss: 0.7083 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6630 - accuracy: 0.6026 - val_loss: 0.7077 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6630 - accuracy: 0.6046 - val_loss: 0.7080 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6631 - accuracy: 0.6013 - val_loss: 0.7076 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6633 - accuracy: 0.6021 - val_loss: 0.7076 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6634 - accuracy: 0.6033 - val_loss: 0.7077 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6630 - accuracy: 0.6018 - val_loss: 0.7074 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6632 - accuracy: 0.6023 - val_loss: 0.7089 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6632 - accuracy: 0.6016 - val_loss: 0.7076 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6629 - accuracy: 0.6064 - val_loss: 0.7084 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6630 - accuracy: 0.6049 - val_loss: 0.7078 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 8us/sample - loss: 0.6633 - accuracy: 0.6049 - val_loss: 0.7089 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6630 - accuracy: 0.6061 - val_loss: 0.7086 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6630 - accuracy: 0.6026 - val_loss: 0.7080 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6630 - accuracy: 0.6033 - val_loss: 0.7089 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6629 - accuracy: 0.6033 - val_loss: 0.7078 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6632 - accuracy: 0.6076 - val_loss: 0.7085 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6631 - accuracy: 0.6038 - val_loss: 0.7092 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6628 - accuracy: 0.6044 - val_loss: 0.7082 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6630 - accuracy: 0.6023 - val_loss: 0.7077 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6629 - accuracy: 0.6054 - val_loss: 0.7080 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6627 - accuracy: 0.6036 - val_loss: 0.7081 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6628 - accuracy: 0.6061 - val_loss: 0.7082 - val_accuracy: 0.5157
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6633 - accuracy: 0.6059 - val_loss: 0.7093 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6628 - accuracy: 0.6064 - val_loss: 0.7073 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6629 - accuracy: 0.6041 - val_loss: 0.7088 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6628 - accuracy: 0.6028 - val_loss: 0.7071 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6633 - accuracy: 0.6033 - val_loss: 0.7076 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6624 - accuracy: 0.6046 - val_loss: 0.7091 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6626 - accuracy: 0.6044 - val_loss: 0.7083 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6627 - accuracy: 0.6013 - val_loss: 0.7094 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6626 - accuracy: 0.6054 - val_loss: 0.7097 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6631 - accuracy: 0.6064 - val_loss: 0.7077 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6626 - accuracy: 0.6033 - val_loss: 0.7088 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6628 - accuracy: 0.6044 - val_loss: 0.7099 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6631 - accuracy: 0.6051 - val_loss: 0.7102 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6629 - accuracy: 0.6049 - val_loss: 0.7070 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6633 - accuracy: 0.6013 - val_loss: 0.7087 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6627 - accuracy: 0.6038 - val_loss: 0.7099 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6629 - accuracy: 0.6046 - val_loss: 0.7075 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6635 - accuracy: 0.5993 - val_loss: 0.7099 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6635 - accuracy: 0.6107 - val_loss: 0.7078 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6629 - accuracy: 0.6026 - val_loss: 0.7086 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6633 - accuracy: 0.6064 - val_loss: 0.7092 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6626 - accuracy: 0.6023 - val_loss: 0.7088 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6623 - accuracy: 0.6089 - val_loss: 0.7092 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6627 - accuracy: 0.6011 - val_loss: 0.7093 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6623 - accuracy: 0.6094 - val_loss: 0.7096 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6622 - accuracy: 0.6061 - val_loss: 0.7087 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6627 - accuracy: 0.6051 - val_loss: 0.7110 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6624 - accuracy: 0.6087 - val_loss: 0.7096 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6624 - accuracy: 0.6054 - val_loss: 0.7103 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6625 - accuracy: 0.6036 - val_loss: 0.7081 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6625 - accuracy: 0.6033 - val_loss: 0.7115 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6625 - accuracy: 0.6061 - val_loss: 0.7100 - val_accuracy: 0.5167
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6621 - accuracy: 0.6038 - val_loss: 0.7093 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6621 - accuracy: 0.6038 - val_loss: 0.7091 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6624 - accuracy: 0.6059 - val_loss: 0.7107 - val_accuracy: 0.5228

# %%
history.history
# Out:
# {'loss': [0.6623986175082588],
#  'accuracy': [0.60586894],
#  'val_loss': [0.7107164425242417],
#  'val_accuracy': [0.52275026]}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(num=None, figsize=(16, 8), dpi=90, facecolor='w', edgecolor='k')
plt.plot()
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'val'], loc='upper left')
plt.show()
#แถวๆ100รอบคือจุดหยุด

# %%
train_acc = list()
val_acc = list()
for i in range(0,100):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6629 - accuracy: 0.6097 - val_loss: 0.7098 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6621 - accuracy: 0.6044 - val_loss: 0.7076 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6623 - accuracy: 0.6061 - val_loss: 0.7092 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6624 - accuracy: 0.6036 - val_loss: 0.7085 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6620 - accuracy: 0.6041 - val_loss: 0.7104 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - ETA: 0s - loss: 0.6699 - accuracy: 0.58 - 0s 10us/sample - loss: 0.6624 - accuracy: 0.6069 - val_loss: 0.7093 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6620 - accuracy: 0.6074 - val_loss: 0.7104 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6620 - accuracy: 0.6071 - val_loss: 0.7089 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6619 - accuracy: 0.6081 - val_loss: 0.7100 - val_accuracy: 0.5157
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6625 - accuracy: 0.6071 - val_loss: 0.7081 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6627 - accuracy: 0.6076 - val_loss: 0.7101 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6622 - accuracy: 0.6079 - val_loss: 0.7090 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6619 - accuracy: 0.6059 - val_loss: 0.7101 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 15us/sample - loss: 0.6619 - accuracy: 0.6049 - val_loss: 0.7090 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 13us/sample - loss: 0.6618 - accuracy: 0.6094 - val_loss: 0.7114 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6620 - accuracy: 0.6071 - val_loss: 0.7070 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6633 - accuracy: 0.6013 - val_loss: 0.7116 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6617 - accuracy: 0.6064 - val_loss: 0.7082 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6618 - accuracy: 0.6056 - val_loss: 0.7112 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6622 - accuracy: 0.6064 - val_loss: 0.7094 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6618 - accuracy: 0.6044 - val_loss: 0.7103 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6617 - accuracy: 0.6089 - val_loss: 0.7095 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6618 - accuracy: 0.6071 - val_loss: 0.7093 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6619 - accuracy: 0.6059 - val_loss: 0.7097 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6622 - accuracy: 0.6066 - val_loss: 0.7112 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 12us/sample - loss: 0.6619 - accuracy: 0.6081 - val_loss: 0.7104 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6619 - accuracy: 0.6084 - val_loss: 0.7096 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6624 - accuracy: 0.6026 - val_loss: 0.7109 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6617 - accuracy: 0.6064 - val_loss: 0.7102 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6614 - accuracy: 0.6084 - val_loss: 0.7091 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6617 - accuracy: 0.6076 - val_loss: 0.7098 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6616 - accuracy: 0.6094 - val_loss: 0.7112 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6617 - accuracy: 0.6097 - val_loss: 0.7079 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6618 - accuracy: 0.6076 - val_loss: 0.7099 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6618 - accuracy: 0.6054 - val_loss: 0.7102 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6617 - accuracy: 0.6059 - val_loss: 0.7092 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6616 - accuracy: 0.6046 - val_loss: 0.7112 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6619 - accuracy: 0.6071 - val_loss: 0.7093 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6615 - accuracy: 0.6064 - val_loss: 0.7102 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6614 - accuracy: 0.6089 - val_loss: 0.7090 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 8us/sample - loss: 0.6613 - accuracy: 0.6117 - val_loss: 0.7089 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6617 - accuracy: 0.6066 - val_loss: 0.7115 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6612 - accuracy: 0.6084 - val_loss: 0.7084 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6612 - accuracy: 0.6069 - val_loss: 0.7099 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6612 - accuracy: 0.6109 - val_loss: 0.7099 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6610 - accuracy: 0.6087 - val_loss: 0.7101 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6609 - accuracy: 0.6081 - val_loss: 0.7105 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6612 - accuracy: 0.6099 - val_loss: 0.7090 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6612 - accuracy: 0.6092 - val_loss: 0.7101 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6613 - accuracy: 0.6089 - val_loss: 0.7098 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6619 - accuracy: 0.6044 - val_loss: 0.7080 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6617 - accuracy: 0.6102 - val_loss: 0.7099 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6610 - accuracy: 0.6081 - val_loss: 0.7110 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6614 - accuracy: 0.6076 - val_loss: 0.7087 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6613 - accuracy: 0.6104 - val_loss: 0.7113 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6614 - accuracy: 0.6087 - val_loss: 0.7098 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6611 - accuracy: 0.6094 - val_loss: 0.7084 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6609 - accuracy: 0.6094 - val_loss: 0.7104 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 8us/sample - loss: 0.6608 - accuracy: 0.6099 - val_loss: 0.7106 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6607 - accuracy: 0.6092 - val_loss: 0.7109 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6607 - accuracy: 0.6109 - val_loss: 0.7097 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6614 - accuracy: 0.6064 - val_loss: 0.7086 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6611 - accuracy: 0.6099 - val_loss: 0.7116 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6612 - accuracy: 0.6092 - val_loss: 0.7105 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6605 - accuracy: 0.6099 - val_loss: 0.7100 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6604 - accuracy: 0.6097 - val_loss: 0.7114 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6613 - accuracy: 0.6051 - val_loss: 0.7113 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6608 - accuracy: 0.6094 - val_loss: 0.7099 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6614 - accuracy: 0.6064 - val_loss: 0.7094 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6612 - accuracy: 0.6071 - val_loss: 0.7101 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6609 - accuracy: 0.6056 - val_loss: 0.7077 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6614 - accuracy: 0.6061 - val_loss: 0.7134 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6605 - accuracy: 0.6104 - val_loss: 0.7085 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6612 - accuracy: 0.6097 - val_loss: 0.7116 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 8us/sample - loss: 0.6605 - accuracy: 0.6099 - val_loss: 0.7101 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6609 - accuracy: 0.6081 - val_loss: 0.7109 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6607 - accuracy: 0.6117 - val_loss: 0.7093 - val_accuracy: 0.5217
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6606 - accuracy: 0.6079 - val_loss: 0.7125 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6606 - accuracy: 0.6092 - val_loss: 0.7110 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6606 - accuracy: 0.6097 - val_loss: 0.7092 - val_accuracy: 0.5207
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6604 - accuracy: 0.6107 - val_loss: 0.7118 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6602 - accuracy: 0.6074 - val_loss: 0.7099 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 8us/sample - loss: 0.6603 - accuracy: 0.6076 - val_loss: 0.7126 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6607 - accuracy: 0.6102 - val_loss: 0.7111 - val_accuracy: 0.5298
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6604 - accuracy: 0.6089 - val_loss: 0.7105 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6610 - accuracy: 0.6084 - val_loss: 0.7147 - val_accuracy: 0.5329
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6611 - accuracy: 0.6114 - val_loss: 0.7102 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6602 - accuracy: 0.6114 - val_loss: 0.7106 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6603 - accuracy: 0.6117 - val_loss: 0.7126 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6604 - accuracy: 0.6122 - val_loss: 0.7099 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6606 - accuracy: 0.6104 - val_loss: 0.7110 - val_accuracy: 0.5278
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6604 - accuracy: 0.6099 - val_loss: 0.7109 - val_accuracy: 0.5308
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 8us/sample - loss: 0.6601 - accuracy: 0.6119 - val_loss: 0.7127 - val_accuracy: 0.5288
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6604 - accuracy: 0.6076 - val_loss: 0.7099 - val_accuracy: 0.5258
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6604 - accuracy: 0.6087 - val_loss: 0.7111 - val_accuracy: 0.5238
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6601 - accuracy: 0.6099 - val_loss: 0.7111 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6600 - accuracy: 0.6122 - val_loss: 0.7120 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 9us/sample - loss: 0.6602 - accuracy: 0.6104 - val_loss: 0.7129 - val_accuracy: 0.5228
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 11us/sample - loss: 0.6602 - accuracy: 0.6099 - val_loss: 0.7111 - val_accuracy: 0.5248
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 10us/sample - loss: 0.6612 - accuracy: 0.6059 - val_loss: 0.7104 - val_accuracy: 0.5298

# %%
#y_predict = np.round(model.predict(X_test_norm)) #ค่าที่ได้จะอยุ่0ถึง1 เลยต้องroundปัดให้เป็น0กับ1ไปเลย
#y_predict = [i[0] for i in y_predict.tolist()]
#sum(y_predict == y_test)/len(y_test)

# %%
y_predict = np.round(model.predict(X_test_norm)) #ค่าที่ได้จะอยุ่0ถึง1 เลยต้องroundปัดให้เป็น0กับ1ไปเลย
y_predict = np.array([i[0] for i in y_predict.tolist()])
sum(y_predict == y_test)/len(y_test)
# Out:
# 0.5453074433656958

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
target_names = ['negative', 'positive']
C = confusion_matrix(y_test,y_predict) 
C = C / C.astype(np.float).sum(axis=1)*100
sns.heatmap(C, annot=True, fmt=".2f",cmap="GnBu",xticklabels=target_names, yticklabels=target_names)
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

# %% [markdown]
# ![](https://i.pinimg.com/originals/4f/54/29/4f5429df5ea6361fa8d3f08dfcdccdf9.jpg)
